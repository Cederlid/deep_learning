# %%
import torch
import torch.nn as nn

# %% [markdown]
# ## Välkomna till denna MYCKET viktiga gruppuppgift!
#
# Er utmaning är att gå igenom följande CNN-class nedan, och sedan förstå varenda steg i forward()-metoden.
#
# Specifikt vill jag att ni förstår input- och output size för varje steg.
#
# **Uppgift**
# * Fyll i varje kommentarsfält i koden nedan med vad input- resp output size blir efter varje operation
#
# Till er hjälp har ni tillgång till PDF:er som vi gått igenom under föreläsningen. Gå igenom tillsammans, om så behövs!
#
# Diskutera i grupp steg-för-steg! Anteckna/rita om ni behöver för att förklara för era kamrater.
#
#
#
# **bonus 1** om ni hinner bli klara:
# * Hur många parametrar har varje layer?
# * Hur många parametrar har nätverket totalt?
# * Kan ni komma fram till en formel för antalet parametrar per lager? Total parameters = (kernel_height × kernel_width × in_channels + 1) × out_channels
#
# **bonus 2**: Leta runt på nätet efter en grym visualisering av filter-aktiveringar. Visa upp för klassen!
#
#
# **Förutsättningar**
#
# Anta att vi jobbar med ett dataset med RGB-bilder av storleken 28x28x3, och att vi försöker lösa ett multiclass-problem med 10 möjliga klasser.

# %% [markdown]
# ---
#
# CNNModel nedan.

# %%
class CNNModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=(3, 3), padding='same')
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=(3, 3), padding='same')
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3), padding='same')
        
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=(2, 2))

        self.flat = nn.Flatten()

        # Adjust the input size for fc4 based on the output of the final pooling layer
        self.fc4 = nn.Linear(576, 512)
        self.fc5 = nn.Linear(512, 10)

    def forward(self, x):
        # Input = 28 x 28 x 3
        x = self.relu(self.conv1(x))
        # Output = 28 x 28 x 32

        # Input = 28 x 28 x 32
        x = self.pool(x)
        # Output = 14 x 14 x 32
        # Input = 14 x 14 x 32
        x = self.relu(self.conv2(x))
        # Output = 14 x 14 x 64

        # Input = 14 x 14 x 64
        x = self.pool(x)
        # Output = 7 x 7 x 64

        # Input = 7 x 7 x 64
        x = self.relu(self.conv3(x))
        # Output = 7 x 7 x 64

        # Input =7 x 7 x 64 
        x = self.pool(x)
        # Output = 3 x 3 x 64

        # GÖMD LEDTRÅD HAHA, tacka Wijdan
      
        # GÖMD LEDTRÅD #2 HAHA, tacka John
        # Input = 3 x 3 x 64
        x = self.flat(x)
        # Output = 576
        # Input = 576
        x = self.relu(self.fc4(x))
        # Output = 512

        # Input = 512
        x = self.fc5(x)              
        # Output =10 

        return x

# %%
model = CNNModel()
print(model)
